# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str:
    """Generate a complete essay draft for given topic."""
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an eassay writer. Given the user's topic, write a complete essay draft.
    Output : A string representing the full draft of the essay.
    
    User topic:
    {topic}
    """
    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %%
#initial draft
# draft_v1 = generate_draft(topic="driverless cars", model="openai:gpt-4o")

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:
    """
    takes a previously generated essay draft and provides constructive feedback.
    """

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an eassay writer. Your task is to take a previously generated essay draft and provide a constructive feedback.
    Output : A string with feedback in paragraph form.
    
    Essay Draft:
    {draft}
    
    Requirements:
    The feedback should be critical but constructive.
    It should address issues such as structure, clarity, strength of argument, and writing style.
    The function should send the draft to the model and return its response.

    You do not need to rewrite the essay at this step—just analyze and reflect on it.
    """
    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:
    """
    improves a given essay draft based on feedback from a reflection step.
    """
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f""" 
    You are an eassay writer. Your task is to improve a given essay draft based on feedback from a reflection step.
    Output : A string containing the revised and improved essay.
    
    original draft:
    {original_draft}
    
    reflection:
    {reflection}
    
    Requirements:
    * The revised draft should address the issues mentioned in the feedback.
    * It should improve clarity, coherence, argument strength, and overall flow.
    * The function should use the feedback to guide the revision, and return only the final revised essay.
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )
    
    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Regulation of Social Media Platforms: A Necessity or Overreach?
#
# Introduction
#
# In the digital age, social media platforms have become quintessential components of daily life, influencing how we communicate, consume information, and shape personal and public discourse. With this expansive influence, questions arise concerning whether these platforms should be regulated by the government. Advocates for regulation argue that it is necessary to ensure transparency, protect user privacy, and combat misinformation, while opponents warn of potential infringements on freedom of expression and innovation. This essay explores both the advantages and drawbacks of government regulation of social media, aiming to strike a balance between protecting public interests and preserving individual freedoms.
#
# The Case for Regulation
#
# Over the past decade, social media platforms have evolved from mere communication tools to major players in shaping public opinion and political landscapes. One of the strongest arguments for government regulation is the increasing concern over privacy breaches and data misuse. Social media companies possess vast amounts of personal data, and high-profile incidents, such as the Cambridge Analytica scandal, have highlighted the potential for misuse. Government regulation could enforce stricter data protection policies, ensuring that users’ personal information is safeguarded against unauthorized access and exploitation.
#
# Moreover, regulation could address the rampant spread of misinformation and harmful content online. During major events, such as elections or health crises like the COVID-19 pandemic, social media becomes a breeding ground for fake news and conspiracy theories, often with detrimental real-world impacts. Government oversight could mandate platforms to implement robust fact-checking and content moderation measures, reducing the spread of false information and fostering a more informed public discourse.
#
# Furthermore, regulating social media platforms could help establish standards of accountability. Currently, many platforms exercise immense power in determining which content is prioritized or suppressed, often without transparent criteria. A regulatory framework could ensure these decisions are subject to public scrutiny, promoting greater transparency and accountability.
#
# The Case Against Regulation
#
# Conversely, opponents of government regulation argue that such measures could stifle freedom of expression, a fundamental democratic principle. Social media serves as a vital platform for diverse voices and opinions, including dissenting and marginalized perspectives that might be suppressed through government intervention. There is a risk that regulation could lead to censorship, where governments could impose biased or politically motivated restrictions on speech.
#
# Additionally, the fast-paced nature of social media innovation may be hindered by stringent regulations. Platforms must constantly evolve to cater to users’ needs and preferences, and excessive government intervention might stifle this innovation, ultimately diminishing user experience and market competition. The regulatory landscape could become a bureaucratic maze, slowing down progress and creativity.
#
# Moreover, critics highlight the difficulty of implementing fair and universal regulations in the global digital space. Social media platforms operate across borders, following different jurisdictions and laws, making it challenging for any single government to enforce comprehensive regulations effectively. This complexity could lead to inconsistent rules and standards, causing confusion and inefficiency.
#
# Finding a Balance
#
# The debate over social media regulation underscores the need for a balanced approach that protects public interests without compromising individual freedoms. Instead of imposing heavy-handed regulations, governments could collaborate with social media platforms to develop guidelines and best practices that encourage self-regulation and industry standards. This cooperative approach can ensure that platforms are held accountable for their actions while maintaining the flexibility to innovate and adapt to changing digital landscapes.
#
# Additionally, fostering digital literacy among users can empower them to navigate social media responsibly, discerning credible information from misleading content. Public education initiatives can equip users with critical thinking skills necessary to engage thoughtfully in the digital space.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government presents a complex conundrum at the intersection of technology, society, and governance. While there is a compelling case for regulation to protect privacy, combat misinformation, and enforce accountability, there is equally a need to safeguard freedom of expression and promote innovation. Ultimately, the goal should be to devise a regulatory approach that respects the dynamic nature of social media while ensuring that it serves the public good. Striking this balance will require thoughtful dialogue and cooperation between governments, platforms, and users alike.
#
# 🧠 Feedback:
#
# The draft offers a clear and well-organized overview of both sides of the social-media regulation debate, but it would benefit from a stronger, more narrowly defined thesis statement early on to guide the reader through your specific line of inquiry. Your introduction effectively sets the scene, yet you might streamline some of the more abstract phrasing (“quintessential components”) in favor of concise language that immediately signals your argument’s direction. Each body section is thematically focused, but the use of transitional adverbs such as “moreover” becomes repetitive; consider varying your connectors and tightening paragraph openings to improve flow. The “Case for” and “Case Against” sections do a good job of summarizing common talking points, though they rely heavily on general examples; you could strengthen your credibility by citing recent studies, statistics or specific policy proposals rather than solely invoking high-profile scandals. The “Finding a Balance” section introduces a cooperative solution, but it reads as somewhat generic—explore more concrete frameworks or real-world pilot programs that illustrate how government–industry collaboration might work. Finally, your conclusion restates key ideas neatly but misses an opportunity to propose a clear model or call to action; closing with a focused recommendation or set of guiding principles would give your essay greater persuasive power. Throughout, the tone is appropriately formal, but varying sentence length and incorporating more active verbs will enliven your style and maintain reader engagement.
#
# ✍️ Revised:
#
# Title: Navigating Social Media Regulation: Striking the Right Balance
#
# Introduction
#
# Social media platforms have become integral to modern communication, drastically influencing how we share information and engage in public discourse. With this evolving role, the debate over whether governments should regulate these platforms intensifies. Advocates of regulation assert the need for stringent measures to ensure user privacy, transparency, and curb misinformation. In contrast, opponents caution against potential infringements on freedom of expression and hindrance to innovation. This essay argues for a balanced regulatory approach that upholds public interests while preserving individual liberties and fostering industry growth.
#
# The Case for Regulation
#
# Social media's transformation into a pivotal force in shaping societal and political landscapes underscores the necessity for governmental oversight. A key argument for regulation is the rampant privacy breaches and data misuse that highlight the risk of unregulated data handling. Incidents such as the Cambridge Analytica scandal powerfully illustrate the potential for abuse, underscoring the demand for regulations that mandate rigorous data protection and privacy standards. Recent studies indicate that robust privacy laws can lead to significant reductions in data breaches, offering vital protection for consumers.
#
# Another compelling reason for regulation is the pervasive spread of misinformation, particularly evident during events like elections or the COVID-19 crisis. Research by MIT found that false news spreads more rapidly on Twitter than truthful stories, illustrating the urgent need for platforms to implement effective fact-checking and content moderation strategies. Government intervention could set clear guidelines to mitigate the damaging effects of misinformation, promoting a more informed and healthy public discourse.
#
# Furthermore, regulation could establish clear standards for accountability and transparency. Currently, the algorithms that determine content visibility lack transparency, creating room for bias and manipulation. A regulatory framework could enforce disclosure of these criteria, thus holding platforms accountable for their content curation decisions.
#
# The Case Against Regulation
#
# On the other hand, critics argue that government regulation might stifle freedom of expression, a cornerstone of democratic societies. Social media provides a crucial outlet for marginalized voices that might otherwise be drowned out in traditional media. Research indicates that regulation, if not carefully designed, could inadvertently lead to censorship or restrictions heavily influenced by political biases, thereby threatening diverse discourse.
#
# Additionally, stringent regulation could hamper the fast-paced innovation characteristic of social media. Platforms constantly evolve to meet user demands, and excessive government oversight may impede this growth, stifling competition and innovation. Analysts claim that the European Union's approach to digital markets has sometimes led to over-compliance and reduced market dynamism, cautioning against excessive regulatory frameworks.
#
# The challenge of developing universally applicable regulations in a fragmented global landscape also complicates the regulatory argument. Social media operating under varying national laws makes it difficult to enforce consistent rules, which could result in a convoluted and inefficient regulatory apparatus.
#
# Finding a Balance
#
# To address these challenges, a hybrid approach that blends regulation with industry cooperation could be more effective. The implementation of collaborative frameworks, such as the Digital Services Act in the EU, demonstrates the potential of cooperative regulation. This model allows governments to set broad standards, letting platforms adapt as necessary while being held accountable.
#
# Educating users through digital literacy programs is another crucial component of this balanced strategy, empowering individuals to navigate and critically engage with online content. Initiatives like Finland's Ministry of Education-led programs against misinformation exemplify practical approaches to fostering an informed citizenry.
#
# Conclusion
#
# The regulation of social media necessitates a nuanced balance between safeguarding public interests and protecting individual freedoms. While there is a clear need for measures to enhance privacy and curb misinformation, any regulatory model must also support freedom of expression and encourage innovation. Achieving this balance requires a cooperative effort, involving governments, industry, and users. By advocating for transparency, accountability, and education, we can foster a social media landscape that serves the public good while respecting the dynamic nature of digital innovation.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Regulation of Social Media Platforms: A Necessity or Overreach?
#
# Introduction
#
# In the digital age, social media platforms have become quintessential components of daily life, influencing how we communicate, consume information, and shape personal and public discourse. With this expansive influence, questions arise concerning whether these platforms should be regulated by the government. Advocates for regulation argue that it is necessary to ensure transparency, protect user privacy, and combat misinformation, while opponents warn of potential infringements on freedom of expression and innovation. This essay explores both the advantages and drawbacks of government regulation of social media, aiming to strike a balance between protecting public interests and preserving individual freedoms.
#
# The Case for Regulation
#
# Over the past decade, social media platforms have evolved from mere communication tools to major players in shaping public opinion and political landscapes. One of the strongest arguments for government regulation is the increasing concern over privacy breaches and data misuse. Social media companies possess vast amounts of personal data, and high-profile incidents, such as the Cambridge Analytica scandal, have highlighted the potential for misuse. Government regulation could enforce stricter data protection policies, ensuring that users’ personal information is safeguarded against unauthorized access and exploitation.
#
# Moreover, regulation could address the rampant spread of misinformation and harmful content online. During major events, such as elections or health crises like the COVID-19 pandemic, social media becomes a breeding ground for fake news and conspiracy theories, often with detrimental real-world impacts. Government oversight could mandate platforms to implement robust fact-checking and content moderation measures, reducing the spread of false information and fostering a more informed public discourse.
#
# Furthermore, regulating social media platforms could help establish standards of accountability. Currently, many platforms exercise immense power in determining which content is prioritized or suppressed, often without transparent criteria. A regulatory framework could ensure these decisions are subject to public scrutiny, promoting greater transparency and accountability.
#
# The Case Against Regulation
#
# Conversely, opponents of government regulation argue that such measures could stifle freedom of expression, a fundamental democratic principle. Social media serves as a vital platform for diverse voices and opinions, including dissenting and marginalized perspectives that might be suppressed through government intervention. There is a risk that regulation could lead to censorship, where governments could impose biased or politically motivated restrictions on speech.
#
# Additionally, the fast-paced nature of social media innovation may be hindered by stringent regulations. Platforms must constantly evolve to cater to users’ needs and preferences, and excessive government intervention might stifle this innovation, ultimately diminishing user experience and market competition. The regulatory landscape could become a bureaucratic maze, slowing down progress and creativity.
#
# Moreover, critics highlight the difficulty of implementing fair and universal regulations in the global digital space. Social media platforms operate across borders, following different jurisdictions and laws, making it challenging for any single government to enforce comprehensive regulations effectively. This complexity could lead to inconsistent rules and standards, causing confusion and inefficiency.
#
# Finding a Balance
#
# The debate over social media regulation underscores the need for a balanced approach that protects public interests without compromising individual freedoms. Instead of imposing heavy-handed regulations, governments could collaborate with social media platforms to develop guidelines and best practices that encourage self-regulation and industry standards. This cooperative approach can ensure that platforms are held accountable for their actions while maintaining the flexibility to innovate and adapt to changing digital landscapes.
#
# Additionally, fostering digital literacy among users can empower them to navigate social media responsibly, discerning credible information from misleading content. Public education initiatives can equip users with critical thinking skills necessary to engage thoughtfully in the digital space.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government presents a complex conundrum at the intersection of technology, society, and governance. While there is a compelling case for regulation to protect privacy, combat misinformation, and enforce accountability, there is equally a need to safeguard freedom of expression and promote innovation. Ultimately, the goal should be to devise a regulatory approach that respects the dynamic nature of social media while ensuring that it serves the public good. Striking this balance will require thoughtful dialogue and cooperation between governments, platforms, and users alike.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">The draft offers a clear and well-organized overview of both sides of the social-media regulation debate, but it would benefit from a stronger, more narrowly defined thesis statement early on to guide the reader through your specific line of inquiry. Your introduction effectively sets the scene, yet you might streamline some of the more abstract phrasing (“quintessential components”) in favor of concise language that immediately signals your argument’s direction. Each body section is thematically focused, but the use of transitional adverbs such as “moreover” becomes repetitive; consider varying your connectors and tightening paragraph openings to improve flow. The “Case for” and “Case Against” sections do a good job of summarizing common talking points, though they rely heavily on general examples; you could strengthen your credibility by citing recent studies, statistics or specific policy proposals rather than solely invoking high-profile scandals. The “Finding a Balance” section introduces a cooperative solution, but it reads as somewhat generic—explore more concrete frameworks or real-world pilot programs that illustrate how government–industry collaboration might work. Finally, your conclusion restates key ideas neatly but misses an opportunity to propose a clear model or call to action; closing with a focused recommendation or set of guiding principles would give your essay greater persuasive power. Throughout, the tone is appropriately formal, but varying sentence length and incorporating more active verbs will enliven your style and maintain reader engagement.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating Social Media Regulation: Striking the Right Balance
#
# Introduction
#
# Social media platforms have become integral to modern communication, drastically influencing how we share information and engage in public discourse. With this evolving role, the debate over whether governments should regulate these platforms intensifies. Advocates of regulation assert the need for stringent measures to ensure user privacy, transparency, and curb misinformation. In contrast, opponents caution against potential infringements on freedom of expression and hindrance to innovation. This essay argues for a balanced regulatory approach that upholds public interests while preserving individual liberties and fostering industry growth.
#
# The Case for Regulation
#
# Social media's transformation into a pivotal force in shaping societal and political landscapes underscores the necessity for governmental oversight. A key argument for regulation is the rampant privacy breaches and data misuse that highlight the risk of unregulated data handling. Incidents such as the Cambridge Analytica scandal powerfully illustrate the potential for abuse, underscoring the demand for regulations that mandate rigorous data protection and privacy standards. Recent studies indicate that robust privacy laws can lead to significant reductions in data breaches, offering vital protection for consumers.
#
# Another compelling reason for regulation is the pervasive spread of misinformation, particularly evident during events like elections or the COVID-19 crisis. Research by MIT found that false news spreads more rapidly on Twitter than truthful stories, illustrating the urgent need for platforms to implement effective fact-checking and content moderation strategies. Government intervention could set clear guidelines to mitigate the damaging effects of misinformation, promoting a more informed and healthy public discourse.
#
# Furthermore, regulation could establish clear standards for accountability and transparency. Currently, the algorithms that determine content visibility lack transparency, creating room for bias and manipulation. A regulatory framework could enforce disclosure of these criteria, thus holding platforms accountable for their content curation decisions.
#
# The Case Against Regulation
#
# On the other hand, critics argue that government regulation might stifle freedom of expression, a cornerstone of democratic societies. Social media provides a crucial outlet for marginalized voices that might otherwise be drowned out in traditional media. Research indicates that regulation, if not carefully designed, could inadvertently lead to censorship or restrictions heavily influenced by political biases, thereby threatening diverse discourse.
#
# Additionally, stringent regulation could hamper the fast-paced innovation characteristic of social media. Platforms constantly evolve to meet user demands, and excessive government oversight may impede this growth, stifling competition and innovation. Analysts claim that the European Union's approach to digital markets has sometimes led to over-compliance and reduced market dynamism, cautioning against excessive regulatory frameworks.
#
# The challenge of developing universally applicable regulations in a fragmented global landscape also complicates the regulatory argument. Social media operating under varying national laws makes it difficult to enforce consistent rules, which could result in a convoluted and inefficient regulatory apparatus.
#
# Finding a Balance
#
# To address these challenges, a hybrid approach that blends regulation with industry cooperation could be more effective. The implementation of collaborative frameworks, such as the Digital Services Act in the EU, demonstrates the potential of cooperative regulation. This model allows governments to set broad standards, letting platforms adapt as necessary while being held accountable.
#
# Educating users through digital literacy programs is another crucial component of this balanced strategy, empowering individuals to navigate and critically engage with online content. Initiatives like Finland's Ministry of Education-led programs against misinformation exemplify practical approaches to fostering an informed citizenry.
#
# Conclusion
#
# The regulation of social media necessitates a nuanced balance between safeguarding public interests and protecting individual freedoms. While there is a clear need for measures to enhance privacy and curb misinformation, any regulatory model must also support freedom of expression and encourage innovation. Achieving this balance requires a cooperative effort, involving governments, industry, and users. By advocating for transparency, accountability, and education, we can foster a social media landscape that serves the public good while respecting the dynamic nature of digital innovation.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
